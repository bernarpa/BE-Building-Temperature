# %%
conda install numpy

# %%
# matrice thermique
import numpy as np

A = np.zeros((43, 35))
F = np.zeros(34)
C = np.zeros(42)
B = np.zeros(42)
theta = np.zeros(42)
G=np.zeros((42,42))

#nombre de personne
nbp=1
phipersonne = 80 #flux de 80watt par personne en moyenne 

#irradiance moyenne solaire sur l'année 
irradiance = 200

# Données
cw= 1250
cg = 1000
cc = 1000
cis = 700

# Température
Text = 15
Tc = 15

#emissivité
epsilonc=0.92
epsilonis=0.07
epsilonw = 0.85
epsilong = 0.92

#Phi


wc=0.15
wis=0.2
wg=0.01
ww=0.1
wp=0.05

lambdac=2
lambdais=0.03
lambdag=1.2
lambdaw=0.15

rhoc=2800
rhois=16
rhog=2500
rhow=500

S1=S7=S3=S5=Sf=7.5
S6=5
S4=10
S2=10
Sp=2.5

hint=8
hext=25

#Mur3        
G[0][0]=hext*S1
G[1][1]=lambdais*S3/wis
G[2][2]=lambdais*S3/wis
G[3][3]=lambdac*S3/wc
G[4][4]=lambdac*S3/wc
G[5][5]=hint*S3

#Mur 1
G[6][6]=hint*S1
G[7][7]=lambdais*S1/wis
G[8][8]=lambdais*S1/wis
G[9][9]=lambdac*S1/wc
G[10][10]=lambdac*S1/wc
G[11][11]=hint*S1

#Porte b 
G[12][12]=hint*Sp
G[13][13]=lambdaw*Sp/wp
G[14][14]=hint*Sp

#Cloison mur 4
G[15][15]=hint*S4
G[16][16]=lambdaw*S4/ww
G[17][17]=lambdaw*S4/ww
G[18][18]=hint*S4

#Mur 5
G[19][19]=hext*S5
G[20][20]=lambdais*S5/wis
G[21][21]=lambdais*S5/wis
G[22][22]=lambdac*S5/wc
G[23][23]=lambdac*S5/wc
G[24][24]=hint*S5

#Fenetre
G[25][25]=hext*Sf
G[26][26]=lambdag*Sf/wg
G[27][27]=hint*Sf

#Mur 6
G[28][28]=hext*S6
G[29][29]=lambdais*S6/wis
G[30][30]=lambdais*S6/wis
G[31][31]=lambdac*S6/wc
G[32][32]=lambdac*S6/wc
G[33][33]=hint*S6

#Mur 7
G[34][34]=hint*S7
G[35][35]=lambdais*S7/wis
G[36][36]=lambdais*S7/wis
G[37][37]=lambdac*S7/wc
G[38][38]=lambdac*S7/wc
G[39][39]=hint*S7

# MUR 3
A[1, 1] = 1
A[2, 1] = -1
A[2, 2] = 1
A[3, 2] = -1
A[3, 3] = 1
A[4, 3] = -1
A[4, 4] = 1
A[5, 4] = -1
A[5, 5] = 1
A[6, 5] = -1
A[6, 6] = 1

# MUR 1
A[7, 7] = 1
A[8, 7] = -1
A[8, 8] = 1
A[9, 8] = -1
A[9, 9] = 1
A[10, 9] = -1
A[10, 10] = 1
A[11, 10] = -1
A[11, 11] = 1
A[12, 11] = -1
A[12, 6] = 1

# PORTE 6
A[13, 17] = -1
A[13, 13] = 1
A[14, 13] = -1
A[14, 12] = 1
A[15, 12] = -1
A[15, 6] = 1

# MUR 4
A[16, 17]= -1
A[16, 16] = 1
A[17, 16] = -1
A[17, 15] = 1
A[18, 15] = -1
A[18, 14] = 1
A[19, 14] = -1
A[19, 6] = 1

# MUR 5
A[20, 18] = 1
A[21, 18] = -1
A[21, 19] = 1
A[22, 19] = -1
A[22, 20] = 1
A[23, 20] = -1
A[23, 21] = 1
A[24, 21] = -1
A[24, 22] = 1
A[25, 22] = -1
A[25, 17] = 1

# Fenetre
A[26, 23] = 1
A[27, 23] = -1
A[27, 24] = 1
A[28, 24] = -1
A[28, 17] = 1

# MUR 6
A[29, 25] = 1
A[30, 25] = -1
A[30, 26] = 1
A[31, 26] = -1
A[31, 27] = 1
A[32, 27] = -1
A[32, 28] = 1
A[33, 28] = -1
A[33, 29] = 1
A[34, 29] = -1
A[34, 17] = 1

# MUR 7
A[35, 30] = 1
A[36, 30] = -1
A[36, 31] = 1
A[37, 31] = -1
A[37, 32] = 1
A[38, 32] = -1
A[38, 33] = 1
A[39, 33] = -1
A[39, 34] = 1
A[40, 34] = -1
A[40, 17] = 1
A[41, 6] = 1
A[42, 17] = 1

Ap = A[1:, 1:]
ApT = np.transpose(Ap)


F[0] = irradiance*epsilonis*S3
F[5] = phipersonne*nbp
F[16] = phipersonne*nbp
F[17] = irradiance*epsilonis*S5
F[21] = irradiance*epsilonc*S5
F[22] = irradiance*epsilong*Sf
F[24] = irradiance*epsilonis*S6
F[28] = irradiance*epsilonc*S6
F[33] = irradiance*epsilonc*S7


C[1] = rhois*cis*wis*S3
C[3] = rhoc*cc*wc*S3
C[18] = rhois*cis*wis*S5
C[20] = rhoc*cc*wc*S5
C[25] = rhois*cis*wis*S6
C[27] = rhoc*cc*wc*S6
C[30] = rhois*cis*wis*S7
C[32] = rhoc*cc*wc*S7
C[7] = rhois*cis*wis*S1
C[9] = rhoc*cc*wc*S1
C[14] = rhow*cw*ww*S4

B[0] = Text
B[6] = Text
B[19] = Text
B[25] = Text
B[28] = Text
B[34] = Text

#diag
Gd=np.diag(G)
Cd=np.diag(C)

theta = np.linalg.inv(Ap.T @ G @ Ap) @( Ap.T @ G @ B + F)
print(theta)

#formule et test
#theta = np.linalg.inv(Ap.T.dot(G).dot(Ap)).dot(ApT.dot(G).dot(B))
#print(theta)
# Out:
# [ 15.81771392  58.77003436 101.7223548  102.20556841 102.68878201
#  103.49413802  15.80546849  58.76378792 101.72210734 102.20538844
#  102.68866953 103.83066986 104.72808809 103.61812343 104.27937897
#  104.94063451 105.06461993  15.88972413  70.84374534 125.79776655
#  126.41599929 127.03423203  41.44568152  45.42186517  15.88972413
#   70.84374534 125.79776655 126.41599929 127.03423203  16.02910758
#   70.91484541 125.80058324 126.41804779 127.03551234]

# %%
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::nbclient==0.5.13=pyhd8ed1ab_0
#   - conda-forge/noarch::websocket-client==1.3.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::readline==8.1=h46c0cb4_0
#   - conda-forge/noarch::jupyterlab_pygments==0.2.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::argon2-cffi-bindings==21.2.0=py37h5e8e339_1
#   - conda-forge/noarch::nteract_on_jupyter==2.1.3=py_0
#   - conda-forge/linux-64::importlib-metadata==4.11.3=py37h89c1867_1
#   - conda-forge/linux-64::mistune==0.8.4=py37h5e8e339_1005
#   - conda-forge/noarch::flit-core==3.7.1=pyhd8ed1ab_0
#   - conda-forge/noarch::babel==2.9.1=pyh44b312d_0
#   - conda-forge/linux-64::sqlalchemy==1.4.35=py37h540881e_0
#   - conda-forge/noarch::packaging==21.3=pyhd8ed1ab_0
#   - conda-forge/noarch::decorator==5.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::backcall==0.2.0=pyh9f0ad1d_0
#   - conda-forge/noarch::importlib_resources==5.6.0=pyhd8ed1ab_0
#   - conda-forge/noarch::nbconvert-pandoc==6.4.5=pyhd8ed1ab_2
#   - conda-forge/noarch::ipywidgets==7.7.0=pyhd8ed1ab_0
#   - conda-forge/noarch::nbformat==5.3.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::setuptools==62.0.0=py37h89c1867_0
#   - conda-forge/noarch::ptyprocess==0.7.0=pyhd3deb0d_0
#   - conda-forge/linux-64::pysocks==1.7.1=py37h89c1867_5
#   - conda-forge/noarch::parso==0.8.3=pyhd8ed1ab_0
#   - conda-forge/noarch::jinja2==3.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::six==1.16.0=pyh6c4a22f_0
#   - conda-forge/noarch::jupyterlab_server==2.12.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pickleshare==0.7.5=py_1003
#   - conda-forge/noarch::pyparsing==3.0.7=pyhd8ed1ab_0
#   - conda-forge/noarch::pygments==2.11.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::ruamel.yaml.clib==0.2.6=py37h540881e_1
#   - conda-forge/noarch::jupyter-offlinenotebook==0.2.2=pyh1d7be83_0
#   - conda-forge/noarch::jsonschema==4.4.0=pyhd8ed1ab_0
#   - conda-forge/noarch::async_generator==1.10=py_0
#   - conda-forge/noarch::notebook==6.4.10=pyha770c72_0
#   - conda-forge/noarch::send2trash==1.8.0=pyhd8ed1ab_0
#   - conda-forge/noarch::testpath==0.6.0=pyhd8ed1ab_0
#   - conda-forge/noarch::nbconvert==6.4.5=pyhd8ed1ab_2
#   - conda-forge/noarch::certipy==0.1.3=py_0
#   - conda-forge/noarch::requests==2.27.1=pyhd8ed1ab_0
#   - conda-forge/noarch::typing_extensions==4.1.1=pyha770c72_0
#   - conda-forge/linux-64::jupyter_core==4.9.2=py37h89c1867_0
#   - conda-forge/noarch::urllib3==1.26.9=pyhd8ed1ab_0
#   - conda-forge/linux-64::pyrsistent==0.18.1=py37h540881e_1
#   - conda-forge/linux-64::pyzmq==22.3.0=py37h0c0c2a8_2
#   - conda-forge/noarch::mako==1.2.0=pyhd8ed1ab_1
#   - conda-forge/linux-64::certifi==2021.10.8=py37h89c1867_2
#   - conda-forge/noarch::wheel==0.37.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::cffi==1.15.0=py37h036bc23_0
#   - conda-forge/noarch::alembic==1.7.7=pyhd8ed1ab_0
#   - conda-forge/linux-64::brotlipy==0.7.0=py37h540881e_1004
#   - conda-forge/noarch::pexpect==4.8.0=pyh9f0ad1d_2
#   - conda-forge/noarch::jupyter_telemetry==0.1.0=pyhd8ed1ab_1
#   - conda-forge/noarch::python-dateutil==2.8.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::sqlite==3.37.1=h4ff8645_0
#   - conda-forge/linux-64::pycurl==7.45.1=py37haaec8a5_1
#   - conda-forge/noarch::attrs==21.4.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::psutil==5.9.0=py37h540881e_1
#   - conda-forge/linux-64::debugpy==1.5.1=py37hcd2ae1e_0
#   - conda-forge/noarch::zipp==3.8.0=pyhd8ed1ab_0
#   - conda-forge/noarch::defusedxml==0.7.1=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_widgets==1.1.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::jupyterhub-singleuser==1.5.0=py37h89c1867_1
#   - conda-forge/noarch::pamela==1.0.0=py_0
#   - conda-forge/linux-64::jedi==0.18.1=py37h89c1867_1
#   - conda-forge/linux-64::python_abi==3.7=2_cp37m
#   - conda-forge/noarch::nbclassic==0.3.7=pyhd8ed1ab_0
#   - conda-forge/noarch::pandocfilters==1.5.0=pyhd8ed1ab_0
#   - conda-forge/noarch::json5==0.9.5=pyh9f0ad1d_0
#   - conda-forge/linux-64::widgetsnbextension==3.6.0=py37h89c1867_0
#   - conda-forge/noarch::backports.functools_lru_cache==1.6.4=pyhd8ed1ab_0
#   - conda-forge/noarch::pyjwt==2.3.0=pyhd8ed1ab_1
#   - conda-forge/noarch::pyopenssl==22.0.0=pyhd8ed1ab_0
#   - conda-forge/noarch::wcwidth==0.2.5=pyh9f0ad1d_2
#   - conda-forge/linux-64::terminado==0.13.3=py37h89c1867_1
#   - conda-forge/linux-64::cryptography==36.0.2=py37h38fbfac_1
#   - conda-forge/noarch::entrypoints==0.4=pyhd8ed1ab_0
#   - conda-forge/noarch::webencodings==0.5.1=py_1
#   - conda-forge/noarch::jupyter-resource-usage==0.6.1=pyhd8ed1ab_0
#   - conda-forge/noarch::blinker==1.4=py_1
#   - conda-forge/linux-64::tornado==6.1=py37h540881e_3
#   - conda-forge/noarch::prompt-toolkit==3.0.29=pyha770c72_0
#   - conda-forge/noarch::charset-normalizer==2.0.12=pyhd8ed1ab_0
#   - conda-forge/linux-64::sniffio==1.2.0=py37h89c1867_3
#   - conda-forge/noarch::python-fastjsonschema==2.15.3=pyhd8ed1ab_0
#   - conda-forge/noarch::pip==22.0.4=pyhd8ed1ab_0
#   - conda-forge/noarch::nest-asyncio==1.5.5=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_client==7.2.2=pyhd8ed1ab_1
#   - conda-forge/linux-64::ipython==7.32.0=py37h89c1867_0
#   - conda-forge/noarch::traitlets==5.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::soupsieve==2.3.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::python==3.7.12=hb7a2778_100_cpython
#   - conda-forge/linux-64::anyio==3.5.0=py37h89c1867_0
#   - conda-forge/noarch::bleach==5.0.0=pyhd8ed1ab_0
#   - conda-forge/noarch::python-json-logger==2.0.1=pyh9f0ad1d_0
#   - conda-forge/noarch::ipython_genutils==0.2.0=py_1
#   - conda-forge/noarch::idna==3.3=pyhd8ed1ab_0
#   - conda-forge/noarch::prometheus_client==0.14.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::ruamel.yaml==0.17.21=py37h540881e_1
#   - conda-forge/noarch::notebook-shim==0.1.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::jupyterhub-base==1.5.0=py37h89c1867_1
#   - conda-forge/noarch::nbconvert-core==6.4.5=pyhd8ed1ab_2
#   - conda-forge/noarch::backports==1.0=py_2
#   - conda-forge/linux-64::ipykernel==6.12.1=py37h25bab4e_0
#   - conda-forge/noarch::matplotlib-inline==0.1.3=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab==3.3.3=pyhd8ed1ab_0
#   - conda-forge/noarch::oauthlib==3.2.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pytz==2022.1=pyhd8ed1ab_0
#   - conda-forge/noarch::argon2-cffi==21.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pycparser==2.21=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_server==1.16.0=pyhd8ed1ab_1
#   - conda-forge/linux-64::greenlet==1.1.2=py37hd23a5d3_2
#   - conda-forge/linux-64::markupsafe==2.1.1=py37h540881e_1
#   - conda-forge/noarch::beautifulsoup4==4.11.0=pyha770c72_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     libblas-3.9.0              |15_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |15_linux64_openblas          12 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |15_linux64_openblas          12 KB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     numpy-1.21.6               |   py37h976b520_0         6.1 MB  conda-forge
#     openssl-1.1.1o             |       h166bdaf_0         2.1 MB  conda-forge
#     readline-8.1.2             |       h7f8727e_1         354 KB  defaults
#     ------------------------------------------------------------
#                                            Total:        20.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   numpy              conda-forge/linux-64::numpy-1.21.6-py37h976b520_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2021.10.8-ha878542_0 --> 2022.6.15-ha878542_0
#   openssl                                 1.1.1n-h166bdaf_0 --> 1.1.1o-h166bdaf_0
#   readline             conda-forge::readline-8.1-h46c0cb4_0 --> pkgs/main::readline-8.1.2-h7f8727e_1
#
#
#
# Downloading and Extracting Packages
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# ca-certificates-2022 | 149 KB    | ##################################### | 100%
# numpy-1.21.6         | 6.1 MB    | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# libgfortran5-12.1.0  | 1.8 MB    | ##################################### | 100%
# readline-8.1.2       | 354 KB    | ##################################### | 100%
# openssl-1.1.1o       | 2.1 MB    | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# libgfortran-ng-12.1. | 23 KB     | ##################################### | 100%
# libopenblas-0.3.20   | 10.1 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
